# %% [markdown]
# Data Structures - List, Dictionary, Set
#
# & Conditional Statements

# %%
age_list = [24, 25, 26, 27, 28]
print(age_list)

# %%
name_list = ["peter", "mathesh", "thiru", "vinoth", "hari"]
print(name_list)
# Out:
# ['peter', 'mathesh', 'thiru', 'vinoth', 'hari']

# %%
name_list . append("yazhini")
print(name_list)
# Out:
# ['peter', 'mathesh', 'thiru', 'vinoth', 'hari', 'yazhini']

# %%
age_list . insert(2,30)
print(age_list)
# Out:
# [24, 25, 30, 30, 26, 27, 28]

# %%
name_list . remove("yazhini")
print(name_list)
# Out:
# ['peter', 'mathesh', 'thiru', 'vinoth', 'hari']

# %%
age_list.pop()
print(age_list)
# Out:
# [24, 25, 30, 30, 26, 27]

# %%
age_list.extend([29, 30, 26])
print(age_list)
# Out:
# [24, 25, 30, 30, 26, 27, 29, 30, 31, 29, 30, 26]

# %%
age_list.sort(reverse=True)
print("sorted list(descending):", age_list)
# Out:
# sorted list(descending): [31, 30, 30, 30, 30, 29, 29, 27, 26, 26, 25, 24]

# %%
max_age = max(age_list)
min_age = min(age_list)
total_age = sum(age_list)
print("max age:", max_age)
print("min age:", min_age)
print("total age:", total_age)
# Out:
# max age: 31
# min age: 24
# total age: 337

# %%
print("first element:",name_list[0])
# Out:
# first element: peter

# %%
print("last element:",name_list[-1])
# Out:
# last element: hari

# %%
print("element from index 2 to 4:", name_list[2:5])
# Out:
# element from index 2 to 4: ['thiru', 'vinoth', 'hari']

# %%
print("reversed list:",name_list[::-1])
# Out:
# reversed list: ['hari', 'vinoth', 'thiru', 'mathesh', 'peter']

# %%
student_mark ={
    "peter": 90,
    "mathesh": 75,
    "thiru": 88,
    "vinoth": 90,
    "hari": 80
}
print("student_mark:", student_mark)
# Out:
# student_mark: {'peter': 90, 'mathesh': 75, 'thiru': 88, 'vinoth': 90, 'hari': 80}

# %%
print("peter's mark:",student_mark["peter"])
# Out:
# peter's mark: 90

# %%
student_mark["janani"] = 80
print("after adding janani:",student_mark)
# Out:
# after adding janani: {'peter': 90, 'mathesh': 75, 'thiru': 88, 'vinoth': 90, 'hari': 80, 'janani': 80}

# %%
student_mark["peter"]=82
print("after updating peter's mark:",student_mark)
# Out:
# after updating peter's mark: {'peter': 82, 'mathesh': 75, 'thiru': 88, 'vinoth': 90, 'hari': 80, 'janani': 80}

# %%
print("keys:",student_mark.keys())
# Out:
# keys: dict_keys(['peter', 'mathesh', 'thiru', 'vinoth', 'hari', 'janani'])

# %%
print("values:",student_mark.values())
# Out:
# values: dict_values([82, 75, 88, 90, 80, 80])

# %%
print("items:",student_mark.items())
# Out:
# items: dict_items([('peter', 82), ('mathesh', 75), ('thiru', 88), ('vinoth', 90), ('hari', 80), ('janani', 80)])

# %%
my_set = {"a", "e", "i", "o", "u", "a","a", "u" }
print(my_set)
# Out:
# {'a', 'o', 'i', 'u', 'e'}

# %%
my_set.add("s")
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3931302425.py in <cell line: 0>()
# ----> 1 my_set[4] = "s"
#       2 print(my_set)
#
# TypeError: 'set' object does not support item assignment

# %%
'''That means you can't acess or modify elements using index
so try to assign  my_set[4] = "s" python raise a
TypeError: 'set' object does not support item assignment'''

# %%
set1 = {1,3,5,7,9}
set2 = {2,3,5,8,10}
print("set1:",set1)
print("set2:",set2)
# Out:
# set1: {1, 3, 5, 7, 9}
# set2: {2, 3, 5, 8, 10}

# %%
union_set=set1.union(set2)
intersection_set=set1.intersection(set2)
print("union_set:",union_set)
print("intersection_set:",intersection_set)
# Out:
# union_set: {1, 2, 3, 5, 7, 8, 9, 10}
# intersection_set: {3, 5}

# %%
score = int(input("Enter your score(0 to 10):"))
if 0<= score <=10:
  print("Your score is:",score)
else:
  print("Invalid score Please Enter a number between 0 to 10.")

# %%
score = int(input("Enter your score(0 to 10):"))
if 0<= score <=10:
  if score >7:
    print("Performance Category:Above Average")
  elif 4 <= score <=7:
     print("Performance Category:Average")
  else:
     print("Performance Category:Below Average")
# Out:
# Enter your score(0 to 10):8
# Performance Category:Above Average

# %%
score = int(input("Enter your score(0 to 10):"))
if 0<= score <=10:
  if score >7:
    print("Performance Category:Above Average")
    print("Excellent work! Keep it up")
  elif 4 <= score <=7:
     print("Performance Category:Average")
     print("Good job! Give a little hard work for shine Brighter")
  else:
     print("Performance Category:Below Average")
     print("Need to improve your performance")
else:
       print("Invalid score Please Enter a number between 0 to 10.")
# Out:
# Enter your score(0 to 10):8
# Performance Category:Above Average
# Excellent work! Keep it up
