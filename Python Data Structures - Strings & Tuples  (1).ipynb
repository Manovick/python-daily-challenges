# %% [markdown]
# Data Structures - Strings & Tuples

# %%
string1 = "Hello "
string2 = input("Enter your name:")
result = string1 + string2
print(result)
# Out:
# Enter your name:vicky
# Hello vicky

# %%
string1 = "Hello"
string2 = input("Enter your name:")
string3 = ", welcome to python programming"
result = string1 + string2 + string3
print(result)
# Out:
# Enter your name: vicky
# Hello vicky, welcome to python programming

# %%
string = "Hello vicky, welcome to python programming"
print(string)
# Out:
# Hello vicky, welcome to python programming

# %%
print(string[0])
# Out:
# H

# %%
print(string[-1])
# Out:
# g

# %%
print(string[0:5])
# Out:
# Hello

# %%
print(string[-11:])
# Out:
# programming

# %%
print(string[::-1])
# Out:
# gnimmargorp nohtyp ot emoclew ,ykciv olleH

# %%
print(string[24:30])
# Out:
# python

# %%
strM = "Python beginner tutorial"
print(strM)
# Out:
# Python beginner tutorial

# %%
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
print(strM.lower())
# Out:
# python beginner tutorial

# %%
print(strM.capitalize())
# Out:
# Python beginner tutorial

# %%
print(strM.count("t"))
# Out:
# 3

# %%
print(strM.replace("Python","Machine Learning"))
# Out:
# Machine Learning beginner tutorial

# %%
t1 = (10,20,30)
t2 = (40,50,60)
print(t1)
print(t2)
# Out:
# (10, 20, 30)
# (40, 50, 60)

# %%
t_combine = t1+t2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
