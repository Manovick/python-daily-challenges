# %% [markdown]
# While loop & Control Statements

# %%
import random


secret_number = random.randint(1, 10)

attempts = 3

while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10): "))


    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue


    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break


    elif guess > secret_number:
        print("Too high. Try again.")


    else:
        print("Too low. Try again.")

    attempts -= 1

else:
    print("Better luck next time!")
# Out:
# Guess the number (between 1 and 10): 5
# Too low. Try again.
# Guess the number (between 1 and 10): 8
# Too high. Try again.
# Guess the number (between 1 and 10): 7
# Too high. Try again.
# Better luck next time!

# %% [markdown]
# For Loop

# %%
num = int(input("Enter a number for which you want the multplication table:"))
for i in range (1 , 11):
 product = num * i
 print(num , "x" , i , "=" , product)
# Out:
# Enter a number for which you want the multplication table:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# Function

# %%
def calculate_BMI(weight , height):
  return weight / (height**2)

weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = calculate_BMI(weight, height)

print("Your BMI is:", format(bmi, ".2f"))
# Out:
# Enter your weight in kg: 54
# Enter your height in meters: 1.2
# Your BMI is: 37.50
